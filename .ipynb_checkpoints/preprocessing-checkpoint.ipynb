# %%
#import packages
from os import listdir
from nipype.interfaces.io import DataSink, SelectFiles, FreeSurferSource # Data i/o
from nipype.interfaces.utility import IdentityInterface, Function     # utility
from nipype.pipeline.engine import Node, Workflow, MapNode        # pypeline engine
from nipype.interfaces.nipy.preprocess import Trim

from nipype.algorithms.rapidart import ArtifactDetect 
from nipype.interfaces.fsl.preprocess import SliceTimer, MCFLIRT, FLIRT, SUSAN, FAST
from nipype.interfaces.fsl.utils import Reorient2Std
from nipype.interfaces.fsl.model import GLM
from nipype.interfaces.fsl.maths import ApplyMask, TemporalFilter
from nipype.interfaces.freesurfer import Resample, Binarize, FSCommand, MRIConvert
from nipype.algorithms.confounds import CompCor


#set output file type for FSL to NIFTI
from nipype.interfaces.fsl.preprocess import FSLCommand
FSLCommand.set_default_output_type('NIFTI')

# MATLAB setup - Specify path to current SPM and the MATLAB's default mode
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('~/spm12')
MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")

# Set study variables
#studyhome = '/Users/catcamacho/Box/FFnHK-Oddball/RESTINGSTATE'
studyhome = '/home/camachocm2/Box_home/CARS_rest'
raw_data = studyhome + '/raw'
output_dir = studyhome + '/proc/preproc'
workflow_dir = studyhome + '/workflows'
subjects_list = open(studyhome + '/misc/subjects.txt').read().splitlines()
#subjects_list = ['101']

template_brain = studyhome + '/templates/MNI152_T1_2mm_brain.nii'

#freesurfer setup
fs_dir = studyhome + '/freesurfer'
FSCommand.set_default_subjects_dir(fs_dir)

proc_cores = 2 # number of cores of processing for the workflows

#vols_to_trim = 4
interleave = True
TR = 2 # in seconds
slice_dir = 3 # 1=x, 2=y, 3=z
resampled_voxel_size = (2,2,2)
fwhm = 4 #fwhm for smoothing with SUSAN

highpass_freq = 0.008 #in Hz
lowpass_freq = 0.09 #in Hz

mask_erosion = 1
mask_dilation = 2

# %%
## File handling Nodes

# Identity node- select subjects
infosource = Node(IdentityInterface(fields=['subject_id']),
                     name='infosource')
infosource.iterables = ('subject_id', subjects_list)


# Data grabber- select fMRI and sMRI
templates = {'func': raw_data + '/{subject_id}/rest/rest_raw.nii'}
selectfiles = Node(SelectFiles(templates), name='selectfiles')

# FreeSurferSource - Data grabber specific for FreeSurfer data
fssource = Node(FreeSurferSource(subjects_dir=fs_dir),
                run_without_submitting=True,
                name='fssource')

# Datasink- where our select outputs will go
substitutions = [('_subject_id_', '')] #output file name substitutions
datasink = Node(DataSink(substitutions = substitutions), name='datasink')
datasink.inputs.base_directory = output_dir
datasink.inputs.container = output_dir

# %%
## Nodes for preprocessing

# Reorient to standard space using FSL
reorientfunc = Node(Reorient2Std(), name='reorientfunc')
reorientstruct = Node(Reorient2Std(), name='reorientstruct')

# Reslice- using MRI_convert 
reslice = Node(MRIConvert(vox_size=resampled_voxel_size, out_type='nii'), 
               name='reslice')

# Segment structural scan
#segment = Node(Segment(affine_regularization='none'), name='segment')
segment = Node(FAST(no_bias=True, 
                    segments=True, 
                    number_classes=3), 
               name='segment')

#Slice timing correction based on interleaved acquisition using FSL
slicetime_correct = Node(SliceTimer(interleaved=interleave, 
                                    slice_direction=slice_dir,
                                   time_repetition=TR),
                            name='slicetime_correct')

# Motion correction
motion_correct = Node(MCFLIRT(save_plots=True, 
                              mean_vol=True), 
                      name='motion_correct')

# Registration- using FLIRT
# The BOLD image is 'in_file', the anat is 'reference', the output is 'out_file'
coreg1 = Node(FLIRT(), name='coreg1')
coreg2 = Node(FLIRT(apply_xfm=True), name = 'coreg2')

# make binary mask 
# structural is the 'in_file', output is 'binary_file'
binarize_struct = Node(Binarize(dilate=mask_dilation, 
                                erode=mask_erosion, 
                                min=1), 
                       name='binarize_struct')

# apply the binary mask to the functional data
# functional is 'in_file', binary mask is 'mask_file', output is 'out_file'
mask_func = Node(ApplyMask(), name='mask_func')


# Artifact detection for scrubbing/motion assessment
art = Node(ArtifactDetect(mask_type='file',
                          parameter_source='FSL',
                          norm_threshold=0.5, #mutually exclusive with rotation and translation thresh
                          zintensity_threshold=3,
                          use_differences=[True, False]),
           name='art')

def converthex_xform(orig_xform):
    from numpy import genfromtxt, savetxt
    from os.path import abspath
    
    orig_matrix = genfromtxt(orig_xform, delimiter='  ',
                             dtype=None, skip_header=0)
    new_xform = 'brainmask_out_flirt.mat'
    savetxt(new_xform, orig_matrix, delimiter='  ')
    
    xform_file = abspath(new_xform)
    return(xform_file)

converthex = Node(name='converthex', 
                  interface=Function(input_names=['orig_xform'], 
                                     output_names=['xform_file'], 
                                     function=converthex_xform))
converthex2 = Node(name='converthex2', 
                   interface=Function(input_names=['orig_xform'], 
                                      output_names=['xform_file'], 
                                      function=converthex_xform))

# %%
# Data QC nodes
def create_coreg_plot(epi,anat):
    import os
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    
    coreg_filename='coregistration.png'
    display = plotting.plot_anat(epi, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'coregistration to anatomy')
    display.add_edges(anat)
    display.savefig(coreg_filename) 
    display.close()
    coreg_file = os.path.abspath(coreg_filename)
    
    return(coreg_file)

def check_mask_coverage(epi,brainmask):
    import os
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nilearn import plotting
    
    maskcheck_filename='maskcheck.png'
    display = plotting.plot_anat(epi, display_mode='ortho',
                                 draw_cross=False,
                                 title = 'brainmask coverage')
    display.add_contours(brainmask,levels=[.5], colors='r')
    display.savefig(maskcheck_filename)
    display.close()
    maskcheck_file = os.path.abspath(maskcheck_filename)

    return(maskcheck_file)

make_coreg_img = Node(name='make_coreg_img',
                      interface=Function(input_names=['epi','anat'],
                                         output_names=['coreg_file'],
                                         function=create_coreg_plot))

make_checkmask_img = Node(name='make_checkmask_img',
                      interface=Function(input_names=['epi','brainmask'],
                                         output_names=['maskcheck_file'],
                                         function=check_mask_coverage))

# %%
# Normalization
register_template = Node(FLIRT(reference=template_brain), 
                         name='register_template')
xfmTissue = MapNode(FLIRT(reference=template_brain,apply_xfm=True), 
                 name='xfmTissue', 
                    iterfield=['in_file'])
xfmFUNC = Node(FLIRT(reference=template_brain,apply_xfm=True), 
               name='xfmFUNC')

def adjust_masks(masks):
    from os.path import abspath
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    from nipype.interfaces.freesurfer.model import Binarize
    #pve0 = csf, pve1 = gm, pve2 = wm
    
    origvols = sorted(masks)
    csf = origvols[0]
    wm = origvols[2]
    
    erode = Binarize()
    erode.inputs.in_file = wm
    erode.inputs.erode = 1
    erode.inputs.min = 0.5
    erode.inputs.max = 1000
    erode.inputs.binary_file = 'WM_seg.nii'
    erode.run()
    
    wm_new = abspath(erode.inputs.binary_file)
    
    vols = []
    vols.append(wm_new)
    vols.append(csf)
    
    return(vols)
    
fix_confs = Node(name='fix_confs',
                 interface=Function(input_names=['masks'], 
                                    output_names=['vols'],
                                    function=adjust_masks))

compcor = Node(CompCor(merge_method='none'), 
               name='compcor')


# Remove all noise (GLM with noise params)
def create_noise_matrix(vols_to_censor,motion_params,comp_noise):
    from numpy import genfromtxt, zeros,concatenate, savetxt
    from os import path
    
    motion = genfromtxt(motion_params, delimiter='  ', dtype=None, skip_header=0)
    comp_noise = genfromtxt(comp_noise, delimiter='\t', dtype=None, skip_header=1)
    censor_vol_list = genfromtxt(vols_to_censor, delimiter='\t', dtype=None, skip_header=0)
    
    try:
        c = censor_vol_list.size
    except:
        c = 0
    
    d=len(comp_noise)

    if c > 1:
        scrubbing = zeros((d,c),dtype=int)
        for t in range(c):
            scrubbing[censor_vol_list[t],t] = 1
        noise_matrix = concatenate((motion,comp_noise,scrubbing),axis=1)
    elif c == 1:
        scrubbing = zeros((d,c),dtype=int)
        scrubbing[censor_vol_list] = 1
        noise_matrix = concatenate((motion,comp_noise,scrubbing),axis=1)
    else:
        noise_matrix = concatenate((motion,comp_noise),axis=1)
    
    noise_file = 'noise_matrix.txt'
    savetxt(noise_file, noise_matrix, delimiter='\t')
    noise_filepath = path.abspath(noise_file)
    
    return(noise_filepath)

noise_mat = Node(name='noise_mat', interface=Function(input_names=['vols_to_censor','motion_params','comp_noise'],
                                                      output_names=['noise_filepath'], 
                                                      function=create_noise_matrix))

denoise = Node(GLM(out_res_name='denoised_residuals.nii', 
                   out_data_name='denoised_func.nii'), 
               name='denoise')

# band pass filtering- all rates are in Hz (1/TR or samples/second)
def bandpass_filter(in_file, lowpass, highpass, TR):
    import numpy as np
    import nibabel as nb
    from os import path
    from nipype.interfaces.afni.preprocess import Bandpass
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    out_file = 'func_filtered.nii'
    bp = Bandpass()
    bp.inputs.highpass = highpass
    bp.inputs.lowpass = lowpass
    bp.inputs.in_file = in_file
    bp.inputs.tr = TR
    bp.inputs.out_file = out_file
    bp.inputs.outputtype = 'NIFTI'
    bp.run()
    
    out_file = path.abspath(out_file)
    return(out_file)

bandpass = Node(name='bandpass', 
                interface=Function(input_names=['in_file','lowpass','highpass','TR'], 
                                   output_names=['out_file'],
                                   function=bandpass_filter))
bandpass.inputs.lowpass = lowpass_freq
bandpass.inputs.highpass = highpass_freq
bandpass.inputs.TR = TR


# Spatial smoothing using FSL
# Brightness threshold should be 0.75 * the contrast between the median brain intensity and the background
def brightthresh(func):
    import nibabel as nib
    from numpy import median, where
    
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    func_nifti1 = nib.load(func)
    func_data = func_nifti1.get_data()
    func_data = func_data.astype(float)
    
    brain_values = where(func_data > 0)
    median_thresh = median(brain_values)
    bright_thresh = 0.75 * median_thresh
    
    return(bright_thresh)

brightthresh_filt = Node(name='brightthresh_filt',
                         interface=Function(input_names=['func'], 
                                            output_names=['bright_thresh'], 
                                            function=brightthresh))    
    
smooth_filt = Node(SUSAN(fwhm=fwhm), name='smooth_filt')


brightthresh_orig = Node(name='brightthresh_orig',
                         interface=Function(input_names=['func'], 
                                            output_names=['bright_thresh'], 
                                            function=brightthresh))    
    
smooth_orig = Node(SUSAN(fwhm=fwhm), name='smooth_orig')
# Out:
#   File "<ipython-input-1-9e0c49463782>", line 57
#     try;c = len(censor_vol_list)
#        ^
# SyntaxError: invalid syntax

# %%
## Preprocessing Workflow

# workflowname.connect([(node1,node2,[('node1output','node2input')]),
#                    (node2,node3,[('node2output','node3input')])
#                    ])

preprocwf = Workflow(name='preprocwf')
preprocwf.connect([(infosource,selectfiles,[('subject_id','subject_id')]), 
                   (infosource, fssource, [('subject_id','subject_id')]),
                   (fssource,reslice, [('brainmask','in_file')]),
                   (reslice, reorientstruct,[('out_file','in_file')]),
                   (selectfiles,reorientfunc,[('func','in_file')]),
                   (reorientstruct,coreg1,[('out_file','reference')]),
                   (reorientstruct,coreg2,[('out_file','reference')]),
                   (reorientstruct,segment,[('out_file','in_files')]),
                   (reorientfunc,slicetime_correct,[('out_file','in_file')]),
                   (slicetime_correct,motion_correct,[('slice_time_corrected_file','in_file')]),
                   (motion_correct,coreg1,[('out_file','in_file')]),
                   (motion_correct,coreg2,[('out_file','in_file')]),
                   (coreg1, converthex,[('out_matrix_file','orig_xform')]),
                   (converthex, coreg2,[('xform_file', 'in_matrix_file')]),
                   (reorientstruct, binarize_struct, [('out_file','in_file')]),
                   (binarize_struct,mask_func,[('binary_file','mask_file')]),
                   (coreg2,mask_func,[('out_file','in_file')]),
                   (mask_func,art,[('out_file','realigned_files')]),
                   (binarize_struct,art,[('binary_file','mask_file')]),
                   (motion_correct,art,[('par_file','realignment_parameters')]),
                   (coreg1,make_coreg_img,[('out_file','epi')]),
                   (reorientstruct,make_coreg_img,[('out_file','anat')]),
                   (binarize_struct,make_checkmask_img,[('binary_file','brainmask')]),
                   (coreg1,make_checkmask_img,[('out_file','epi')]),
                   
                   (reorientstruct,register_template,[('out_file','in_file')]),
                   (mask_func,xfmFUNC,[('out_file','in_file')]),
                   (segment,xfmTissue,[('tissue_class_files','in_file')]),
                   (register_template,converthex2,[('out_matrix_file','orig_xform')]),
                   (converthex2,xfmFUNC,[('xform_file','in_matrix_file')]),
                   (converthex2,xfmTissue,[('xform_file','in_matrix_file')]),
                   (xfmTissue,fix_confs,[('out_file','masks')]),
                   (fix_confs,compcor,[('vols','mask_files')]),
                   (xfmFUNC,compcor,[('out_file','realigned_file')]),
                   (compcor,noise_mat,[('components_file','comp_noise')]),
                   (art,noise_mat,[('outlier_files','vols_to_censor')]),
                   (motion_correct,noise_mat,[('par_file','motion_params')]),
                   (noise_mat,denoise,[('noise_filepath','design')]),
                   (xfmFUNC,denoise,[('out_file','in_file')]),
                   (denoise,bandpass,[('out_data','in_file')]),
                   (bandpass,brightthresh_filt,[('out_file','func')]),
                   (brightthresh_filt,smooth_filt,[('bright_thresh','brightness_threshold')]),
                   (bandpass,smooth_filt,[('out_file','in_file')]), 
                   (denoise,brightthresh_orig,[('out_file','func')]),
                   (brightthresh_orig,smooth_orig,[('bright_thresh','brightness_threshold')]),
                   (denoise,smooth_orig,[('out_data','in_file')]),
                   
                   #(motion_correct,datasink,[('par_file','motion_params')]),
                   (reorientstruct,datasink,[('out_file','resliced_struct')]),
                   #(mask_func,datasink,[('out_file','masked_func')]),
                   (segment,datasink,[('tissue_class_files','tissue_class_files')]),
                   (art,datasink, [('plot_files','art_plot_files')]),
                   #(art,datasink, [('outlier_files','vols_to_censor')]),
                   (make_checkmask_img,datasink,[('maskcheck_file','maskcheck_image')]),
                   (make_coreg_img,datasink,[('coreg_file','coreg_image')]),
                   #(compcor,datasink,[('components_file','components_file')]),
                   (smooth_filt,datasink,[('smoothed_file','smoothed_filt_func')]),
                   (smooth_orig,datasink,[('smoothed_file','smoothed_orig_func')]),
                   (bandpass,datasink,[('out_file','bp_filtered_func')]),
                   (denoise,datasink,[('out_data','denoised_func')])
                  ])
preprocwf.base_dir = workflow_dir
preprocwf.write_graph(graph2use='flat')
preprocwf.run('MultiProc', plugin_args={'n_procs': proc_cores})
# Out:
# 170802-12:21:54,564 workflow INFO:
# 	 Generated workflow graph: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/graph.dot.png (graph2use=flat, simple_form=True).
# 170802-12:21:54,588 workflow INFO:
# 	 Workflow preprocwf settings: ['check', 'execution', 'logging']
# 170802-12:21:54,621 workflow INFO:
# 	 Running in parallel.
# 170802-12:21:54,625 workflow INFO:
# 	 Executing: fssource.a0 ID: 0
# 170802-12:21:54,630 workflow INFO:
# 	 Executing node fssource.a0 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/fssource
# 170802-12:21:54,644 workflow INFO:
# 	 [Job finished] jobname: fssource.a0 jobid: 0
# 170802-12:21:54,646 workflow INFO:
# 	 Executing: selectfiles.a0 ID: 2
# 170802-12:21:54,649 workflow INFO:
# 	 Executing node selectfiles.a0 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/selectfiles
# 170802-12:21:54,667 workflow INFO:
# 	 [Job finished] jobname: selectfiles.a0 jobid: 2
# 170802-12:21:54,669 workflow INFO:
# 	 Executing: reslice.a0 ID: 1
# 170802-12:21:54,674 workflow INFO:
# 	 [Job finished] jobname: reslice.a0 jobid: 1
# 170802-12:21:54,675 workflow INFO:
# 	 Executing: reorientfunc.a0 ID: 3
# 170802-12:21:54,679 workflow INFO:
# 	 [Job finished] jobname: reorientfunc.a0 jobid: 3
# 170802-12:21:54,686 workflow INFO:
# 	 Executing: slicetime_correct.a0 ID: 4
# 170802-12:21:54,691 workflow INFO:
# 	 [Job finished] jobname: slicetime_correct.a0 jobid: 4
# 170802-12:21:54,692 workflow INFO:
# 	 Executing: reorientstruct.a0 ID: 6
# 170802-12:21:54,695 workflow INFO:
# 	 [Job finished] jobname: reorientstruct.a0 jobid: 6
# 170802-12:21:54,697 workflow INFO:
# 	 Executing: motion_correct.a0 ID: 5
# 170802-12:21:54,702 workflow INFO:
# 	 [Job finished] jobname: motion_correct.a0 jobid: 5
# 170802-12:21:54,703 workflow INFO:
# 	 Executing: segment.a0 ID: 7
# 170802-12:21:54,706 workflow INFO:
# 	 [Job finished] jobname: segment.a0 jobid: 7
# 170802-12:21:54,709 workflow INFO:
# 	 Executing: register_template.a0 ID: 8
# 170802-12:21:54,712 workflow INFO:
# 	 [Job finished] jobname: register_template.a0 jobid: 8
# 170802-12:21:54,713 workflow INFO:
# 	 Executing: binarize_struct.a0 ID: 12
# 170802-12:21:54,717 workflow INFO:
# 	 [Job finished] jobname: binarize_struct.a0 jobid: 12
# 170802-12:21:54,720 workflow INFO:
# 	 Executing: converthex2.a0 ID: 9
# 170802-12:21:54,722 workflow INFO:
# 	 [Job finished] jobname: converthex2.a0 jobid: 9
# 170802-12:21:54,724 workflow INFO:
# 	 Executing: coreg1.a0 ID: 13
# 170802-12:21:54,728 workflow INFO:
# 	 [Job finished] jobname: coreg1.a0 jobid: 13
# 170802-12:21:54,731 workflow INFO:
# 	 Executing: xfmTissue.a0 ID: 10
# 170802-12:21:54,739 workflow INFO:
# 	 Adding 3 jobs for mapnode xfmTissue.a0
# 170802-12:21:54,742 workflow INFO:
# 	 Executing: converthex.a0 ID: 14
# 170802-12:21:54,744 workflow INFO:
# 	 [Job finished] jobname: converthex.a0 jobid: 14
# 170802-12:21:54,746 workflow INFO:
# 	 Executing: make_coreg_img.a0 ID: 15
# 170802-12:21:54,750 workflow INFO:
# 	 [Job finished] jobname: make_coreg_img.a0 jobid: 15
# 170802-12:21:54,752 workflow INFO:
# 	 Executing: make_checkmask_img.a0 ID: 16
# 170802-12:21:54,757 workflow INFO:
# 	 [Job finished] jobname: make_checkmask_img.a0 jobid: 16
# 170802-12:21:54,758 workflow INFO:
# 	 Executing: coreg2.a0 ID: 17
# 170802-12:21:54,765 workflow INFO:
# 	 [Job finished] jobname: coreg2.a0 jobid: 17
# 170802-12:21:54,767 workflow INFO:
# 	 Executing: mask_func.a0 ID: 18
# 170802-12:21:54,771 workflow INFO:
# 	 [Job finished] jobname: mask_func.a0 jobid: 18
# 170802-12:21:54,773 workflow INFO:
# 	 Executing: _xfmTissue0 ID: 30
# 170802-12:21:54,774 workflow INFO:
# 	 [Job finished] jobname: _xfmTissue0 jobid: 30
# 170802-12:21:54,776 workflow INFO:
# 	 Executing: xfmFUNC.a0 ID: 19
# 170802-12:21:54,780 workflow INFO:
# 	 [Job finished] jobname: xfmFUNC.a0 jobid: 19
# 170802-12:21:54,781 workflow INFO:
# 	 Executing: art.a0 ID: 21
# 170802-12:21:54,787 workflow INFO:
# 	 [Job finished] jobname: art.a0 jobid: 21
# 170802-12:21:54,791 workflow INFO:
# 	 Executing: _xfmTissue1 ID: 31
# 170802-12:21:54,796 workflow INFO:
# 	 [Job finished] jobname: _xfmTissue1 jobid: 31
# 170802-12:21:54,801 workflow INFO:
# 	 Executing: _xfmTissue2 ID: 32
# 170802-12:21:54,805 workflow INFO:
# 	 [Job finished] jobname: _xfmTissue2 jobid: 32
# 170802-12:21:54,808 workflow INFO:
# 	 Executing: xfmTissue.a0 ID: 10
# 170802-12:21:54,810 workflow INFO:
# 	 [Job finished] jobname: xfmTissue.a0 jobid: 10
# 170802-12:21:54,813 workflow INFO:
# 	 Executing: fix_confs.a0 ID: 11
# 170802-12:21:54,819 workflow INFO:
# 	 [Job finished] jobname: fix_confs.a0 jobid: 11
# 170802-12:21:54,821 workflow INFO:
# 	 Executing: compcor.a0 ID: 20
# 170802-12:21:54,826 workflow INFO:
# 	 [Job finished] jobname: compcor.a0 jobid: 20
# 170802-12:21:54,828 workflow INFO:
# 	 Executing: noise_mat.a0 ID: 22
# 170802-12:21:54,835 workflow INFO:
# 	 [Job finished] jobname: noise_mat.a0 jobid: 22
# 170802-12:21:54,837 workflow INFO:
# 	 Executing: denoise.a0 ID: 23
# 170802-12:21:54,842 workflow INFO:
# 	 [Job finished] jobname: denoise.a0 jobid: 23
# 170802-12:21:54,845 workflow INFO:
# 	 Executing: brightthresh_orig.a0 ID: 24
# 170802-12:21:54,848 workflow INFO:
# 	 [Job finished] jobname: brightthresh_orig.a0 jobid: 24
# 170802-12:21:54,849 workflow INFO:
# 	 Executing: bandpass.a0 ID: 25
# 170802-12:21:54,854 workflow INFO:
# 	 Executing node bandpass.a0 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass
# 170802-12:21:54,885 interface DEBUG:
# 	 highpass_0.008
# 170802-12:21:54,886 interface DEBUG:
# 	 in_file_/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/denoise/denoised_func.nii
# 170802-12:21:54,888 interface DEBUG:
# 	 lowpass_0.09
# 170802-12:21:54,890 interface DEBUG:
# 	 out_file_func_filtered.nii
# 170802-12:21:54,891 interface DEBUG:
# 	 tr_2.0
# 170802-12:21:54,894 interface DEBUG:
# 	 {u'DISPLAY': u':1'}
# 170802-12:21:55,952 interface INFO:
# 	 stderr 2017-08-02T12:21:55.952444:++ 3dBandpass: AFNI version=Debian-16.2.07~dfsg.1-5~nd16.10+1 (Jun 12 2017) [64-bit]
# 170802-12:21:55,955 interface INFO:
# 	 stderr 2017-08-02T12:21:55.952444:++ Authored by: RW Cox
# 170802-12:21:55,968 interface INFO:
# 	 stderr 2017-08-02T12:21:55.952444:*+ WARNING: (-: For most purposes, 3dTproject is superior to 3dBandpass :-)
# 170802-12:21:55,976 interface INFO:
# 	 stderr 2017-08-02T12:21:55.952444:++ Data length = 60  FFT length = 60
# 170802-12:21:55,978 interface INFO:
# 	 stderr 2017-08-02T12:21:55.952444: + bandpass: ntime=60 nFFT=60 dt=2 dFreq=0.00833333 Nyquist=0.25 passband indexes=1..11
# 170802-12:21:55,979 interface INFO:
# 	 stderr 2017-08-02T12:21:55.952444:++ Loading input dataset time series
# 170802-12:21:56,854 workflow INFO:
# 	 Executing: smooth_orig.a0 ID: 28
# 170802-12:21:56,861 workflow INFO:
# 	 [Job finished] jobname: smooth_orig.a0 jobid: 28
# 170802-12:21:56,991 interface INFO:
# 	 stderr 2017-08-02T12:21:56.991827:++ No mask ==> processing all 902629 voxels
# 170802-12:21:56,997 interface INFO:
# 	 stderr 2017-08-02T12:21:56.991827:++ Checking dataset for initial transients [use '-notrans' to skip this test]
# 170802-12:21:58,11 interface INFO:
# 	 stderr 2017-08-02T12:21:58.011898: + No widespread initial positive transient detected :-)
# 170802-12:21:58,515 interface INFO:
# 	 stderr 2017-08-02T12:21:58.515317:++ 60 dimensional data reduced to 19 by:
# 170802-12:21:58,516 interface INFO:
# 	 stderr 2017-08-02T12:21:58.515317:    38 (bandpass), 0 (-ort), 0 (-dsort), 3 (detrend)
# 170802-12:21:58,518 interface INFO:
# 	 stderr 2017-08-02T12:21:58.515317:++ Bandpassing data time series
# 170802-12:21:59,533 interface INFO:
# 	 stderr 2017-08-02T12:21:59.533170:++ Creating output dataset in memory, then writing it
# 170802-12:22:00,35 interface INFO:
# 	 stderr 2017-08-02T12:22:00.035652:++ Output dataset ./func_filtered.nii
# 170802-12:22:01,50 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/func_filtered.nii;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/func_filtered.mat;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/_0xd84c76b7559a944bc99c0c772e04573d_unfinished.json;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/_inputs.pklz;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/_node.pklz
# 170802-12:22:01,52 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/_report
# 170802-12:22:01,61 workflow DEBUG:
# 	 Removing files:
# 170802-12:22:01,65 workflow DEBUG:
# 	 saved results in /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/result_bandpass.pklz
# 170802-12:22:01,70 workflow DEBUG:
# 	 writing post-exec report to /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/_report/report.rst
# 170802-12:22:01,74 workflow DEBUG:
# 	 Finished running bandpass.a0 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass
#
# 170802-12:22:01,78 workflow INFO:
# 	 [Job finished] jobname: bandpass.a0 jobid: 25
# 170802-12:22:01,81 workflow INFO:
# 	 Executing: brightthresh_filt.a0 ID: 26
# 170802-12:22:01,87 workflow INFO:
# 	 Executing node brightthresh_filt.a0 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/brightthresh_filt
# 170802-12:22:01,88 workflow INFO:
# 	 Executing: datasink.a0 ID: 29
# 170802-12:22:01,200 workflow INFO:
# 	 Executing node datasink.a0 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink
# 170802-12:22:01,203 workflow DEBUG:
# 	 Output dir: ['_inputs.pklz', '_report', 'result_datasink.pklz', '_0xad0ce8ab58d1ed6e1a7c5d8d4d741719.json', '_node.pklz']
# 170802-12:22:01,217 workflow DEBUG:
# 	 Output dir: ['_inputs.pklz', '_report', 'result_datasink.pklz', '_0xad0ce8ab58d1ed6e1a7c5d8d4d741719.json', '_node.pklz']
# 170802-12:22:01,224 workflow DEBUG:
# 	 Found hashfiles: ['/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink/_0xad0ce8ab58d1ed6e1a7c5d8d4d741719.json']
# 170802-12:22:01,236 workflow DEBUG:
# 	 Final hashfile: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink/_0x2bb5eb9cc9f651d80f278b5392c44c18.json
# 170802-12:22:01,237 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=True, hash_exists=False
# 170802-12:22:01,251 workflow DEBUG:
# 	 Node hash: 2bb5eb9cc9f651d80f278b5392c44c18
# 170802-12:22:01,252 workflow DEBUG:
# 	 Rerunning node:
# updatehash = False, self.overwrite = None, self._interface.always_run = True, os.path.exists(/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink/_0x2bb5eb9cc9f651d80f278b5392c44c18.json) = False, hash_method = timestamp
# 170802-12:22:01,256 workflow DEBUG:
# 	 Previous node hash = ad0ce8ab58d1ed6e1a7c5d8d4d741719
# 170802-12:22:01,310 workflow DEBUG:
# 	  not previously seen: set(['substitutions'])
# 170802-12:22:01,320 workflow DEBUG:
# 	  values differ in fields: _outputs: [(u'art_plot_files', (u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/art/plot.rest_raw_reoriented_st_mcf_flirt_masked.png', 'd50c0ec3074fc132570dec5c81d45f09')), (u'bp_filtered_func', (u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/func_filtered.nii', 'bdcae0cad06779385ad9d503958219a9')), (u'coreg_image', (u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/make_coreg_img/coregistration.png', 'e6b314a7e0870874cff4ade6fae64726')), (u'denoised_func', (u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/denoise/denoised_func.nii', 'ebfa6e18d6ba6a49d651460442900b98')), (u'maskcheck_image', (u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/make_checkmask_img/maskcheck.png', '230b33a24d4539023db88ecdb9b119e6')), (u'resliced_struct', (u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/reorientstruct/brainmask_out_reoriented.nii', 'e26d74451899d6c27df5fe141c297e28')), (u'smoothed_orig_func', (u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_orig/denoised_func_smooth.nii', '91612dc0ca9bb6e7dd2849d8bddca9e4'))] != [[u'art_plot_files', [u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/art/plot.rest_raw_reoriented_st_mcf_flirt_masked.png', u'd50c0ec3074fc132570dec5c81d45f09']], [u'bp_filtered_func', [u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/func_filtered.nii', u'a779745b6d0cab8dfe22a273ff6d0e47']], [u'components_file', [u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/compcor/components_file.txt', u'fcaf5198fe5d72517ddf74a32cc05fa1']], [u'coreg_image', [u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/make_coreg_img/coregistration.png', u'e6b314a7e0870874cff4ade6fae64726']], [u'denoised_func', [u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/denoise/denoised_func.nii', u'ebfa6e18d6ba6a49d651460442900b98']], [u'maskcheck_image', [u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/make_checkmask_img/maskcheck.png', u'230b33a24d4539023db88ecdb9b119e6']], [u'resliced_struct', [u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/reorientstruct/brainmask_out_reoriented.nii', u'e26d74451899d6c27df5fe141c297e28']], [u'smoothed_orig_func', [u'/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_orig/denoised_func_smooth.nii', u'91612dc0ca9bb6e7dd2849d8bddca9e4']]]
# 170802-12:22:01,324 workflow DEBUG:
# 	 Removing old /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink and its contents
# 170802-12:22:01,327 workflow DEBUG:
# 	 Creating /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink
# 170802-12:22:01,328 workflow DEBUG:
# 	 writing pre-exec report to /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink/_report/report.rst
# 170802-12:22:01,335 workflow DEBUG:
# 	 Executing node
# 170802-12:22:01,341 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 170802-12:22:01,344 interface DEBUG:
# 	 key: resliced_struct files: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/reorientstruct/brainmask_out_reoriented.nii
# 170802-12:22:01,346 interface DEBUG:
# 	 copyfile: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/reorientstruct/brainmask_out_reoriented.nii /home/camachocm2/Box_home/CARS_rest/proc/preproc/resliced_struct/_subject_id_101/brainmask_out_reoriented.nii
# 170802-12:22:01,385 interface DEBUG:
# 	 key: denoised_func files: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/denoise/denoised_func.nii
# 170802-12:22:01,388 interface DEBUG:
# 	 copyfile: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/denoise/denoised_func.nii /home/camachocm2/Box_home/CARS_rest/proc/preproc/denoised_func/_subject_id_101/denoised_func.nii
# 170802-12:22:01,403 interface DEBUG:
# 	 key: coreg_image files: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/make_coreg_img/coregistration.png
# 170802-12:22:01,460 interface DEBUG:
# 	 copyfile: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/make_coreg_img/coregistration.png /home/camachocm2/Box_home/CARS_rest/proc/preproc/coreg_image/_subject_id_101/coregistration.png
# 170802-12:22:01,463 interface DEBUG:
# 	 key: smoothed_orig_func files: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_orig/denoised_func_smooth.nii
# 170802-12:22:01,469 interface DEBUG:
# 	 copyfile: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_orig/denoised_func_smooth.nii /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_orig_func/_subject_id_101/denoised_func_smooth.nii
# 170802-12:22:01,471 interface DEBUG:
# 	 key: art_plot_files files: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/art/plot.rest_raw_reoriented_st_mcf_flirt_masked.png
# 170802-12:22:01,474 interface DEBUG:
# 	 copyfile: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/art/plot.rest_raw_reoriented_st_mcf_flirt_masked.png /home/camachocm2/Box_home/CARS_rest/proc/preproc/art_plot_files/_subject_id_101/plot.rest_raw_reoriented_st_mcf_flirt_masked.png
# 170802-12:22:01,489 interface DEBUG:
# 	 key: maskcheck_image files: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/make_checkmask_img/maskcheck.png
# 170802-12:22:01,491 interface DEBUG:
# 	 copyfile: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/make_checkmask_img/maskcheck.png /home/camachocm2/Box_home/CARS_rest/proc/preproc/maskcheck_image/_subject_id_101/maskcheck.png
# 170802-12:22:01,493 interface DEBUG:
# 	 key: bp_filtered_func files: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/func_filtered.nii
# 170802-12:22:01,495 interface DEBUG:
# 	 copyfile: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/func_filtered.nii /home/camachocm2/Box_home/CARS_rest/proc/preproc/bp_filtered_func/_subject_id_101/func_filtered.nii
# 170802-12:22:02,573 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/brightthresh_filt/_0xe49a699e29026e587b53dbd914defdd8_unfinished.json;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/brightthresh_filt/_inputs.pklz;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/brightthresh_filt/_node.pklz
# 170802-12:22:02,585 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/brightthresh_filt/_report
# 170802-12:22:02,589 workflow DEBUG:
# 	 Removing files:
# 170802-12:22:02,596 workflow DEBUG:
# 	 saved results in /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/brightthresh_filt/result_brightthresh_filt.pklz
# 170802-12:22:02,609 workflow DEBUG:
# 	 writing post-exec report to /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/brightthresh_filt/_report/report.rst
# 170802-12:22:02,623 workflow DEBUG:
# 	 Finished running brightthresh_filt.a0 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/brightthresh_filt
#
# 170802-12:22:02,673 workflow INFO:
# 	 [Job finished] jobname: brightthresh_filt.a0 jobid: 26
# 170802-12:22:02,676 workflow INFO:
# 	 Executing: smooth_filt.a0 ID: 27
# 170802-12:22:02,684 workflow INFO:
# 	 Executing node smooth_filt.a0 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt
# 170802-12:22:02,695 workflow DEBUG:
# 	 Output dir: ['_inputs.pklz', '_report', 'result_smooth_filt.pklz', 'command.txt', '_node.pklz']
# 170802-12:22:02,711 workflow DEBUG:
# 	 Output dir: ['_inputs.pklz', '_report', 'result_smooth_filt.pklz', 'command.txt', '_node.pklz']
# 170802-12:22:02,718 workflow DEBUG:
# 	 Found hashfiles: []
# 170802-12:22:02,721 workflow DEBUG:
# 	 Final hashfile: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/_0xedfa325aaa93c04c23f0bc127b2bc637.json
# 170802-12:22:02,722 workflow DEBUG:
# 	 updatehash=False, overwrite=None, always_run=False, hash_exists=False
# 170802-12:22:02,737 workflow DEBUG:
# 	 Node hash: edfa325aaa93c04c23f0bc127b2bc637
# 170802-12:22:02,738 workflow DEBUG:
# 	 Removing old /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt and its contents
# 170802-12:22:02,760 workflow DEBUG:
# 	 Creating /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt
# 170802-12:22:02,762 workflow DEBUG:
# 	 writing pre-exec report to /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/_report/report.rst
# 170802-12:22:02,766 workflow DEBUG:
# 	 Executing node
# 170802-12:22:02,767 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 170802-12:22:02,767 interface DEBUG:
# 	 brightness_threshold_30.75
# 170802-12:22:02,768 interface DEBUG:
# 	 dimension_3
# 170802-12:22:02,769 interface DEBUG:
# 	 in_file_/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/func_filtered.nii
# 170802-12:22:02,772 interface DEBUG:
# 	 out_file_/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/func_filtered_smooth.nii
# 170802-12:22:02,774 interface DEBUG:
# 	 use_median_1
# 170802-12:22:02,778 workflow INFO:
# 	 Running: susan /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/func_filtered.nii 30.7500000000 1.6986436006 3 1 0 /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/func_filtered_smooth.nii
# 170802-12:22:02,780 interface DEBUG:
# 	 brightness_threshold_30.75
# 170802-12:22:02,782 interface DEBUG:
# 	 dimension_3
# 170802-12:22:02,786 interface DEBUG:
# 	 in_file_/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/bandpass/func_filtered.nii
# 170802-12:22:02,787 interface DEBUG:
# 	 out_file_/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/func_filtered_smooth.nii
# 170802-12:22:02,791 interface DEBUG:
# 	 use_median_1
# 170802-12:22:02,793 interface DEBUG:
# 	 {u'DISPLAY': u':1'}
# 170802-12:22:03,237 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Box_home/CARS_rest/proc/preproc/resliced_struct/_subject_id_101/brainmask_out_reoriented.nii;/home/camachocm2/Box_home/CARS_rest/proc/preproc/resliced_struct/_subject_id_101/brainmask_out_reoriented.mat;/home/camachocm2/Box_home/CARS_rest/proc/preproc/denoised_func/_subject_id_101/denoised_func.nii;/home/camachocm2/Box_home/CARS_rest/proc/preproc/denoised_func/_subject_id_101/denoised_func.mat;/home/camachocm2/Box_home/CARS_rest/proc/preproc/coreg_image/_subject_id_101/coregistration.png;/home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_orig_func/_subject_id_101/denoised_func_smooth.nii;/home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_orig_func/_subject_id_101/denoised_func_smooth.mat;/home/camachocm2/Box_home/CARS_rest/proc/preproc/art_plot_files/_subject_id_101/plot.rest_raw_reoriented_st_mcf_flirt_masked.png;/home/camachocm2/Box_home/CARS_rest/proc/preproc/maskcheck_image/_subject_id_101/maskcheck.png;/home/camachocm2/Box_home/CARS_rest/proc/preproc/bp_filtered_func/_subject_id_101/func_filtered.nii;/home/camachocm2/Box_home/CARS_rest/proc/preproc/bp_filtered_func/_subject_id_101/func_filtered.mat;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink/_0x2bb5eb9cc9f651d80f278b5392c44c18_unfinished.json;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink/_inputs.pklz;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink/_node.pklz
# 170802-12:22:03,238 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink/_report
# 170802-12:22:03,253 workflow DEBUG:
# 	 Removing files:
# 170802-12:22:03,260 workflow DEBUG:
# 	 saved results in /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink/result_datasink.pklz
# 170802-12:22:03,275 workflow DEBUG:
# 	 writing post-exec report to /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink/_report/report.rst
# 170802-12:22:03,283 workflow DEBUG:
# 	 Finished running datasink.a0 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/datasink
#
# 170802-12:22:03,312 workflow INFO:
# 	 [Job finished] jobname: datasink.a0 jobid: 29
# 170802-12:22:23,844 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/func_filtered_smooth.nii;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/func_filtered_smooth.mat;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/_0xedfa325aaa93c04c23f0bc127b2bc637_unfinished.json;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/command.txt;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/_inputs.pklz;/home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/_node.pklz
# 170802-12:22:23,845 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/_report
# 170802-12:22:23,848 workflow DEBUG:
# 	 Removing files:
# 170802-12:22:23,852 workflow DEBUG:
# 	 saved results in /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/result_smooth_filt.pklz
# 170802-12:22:23,854 workflow DEBUG:
# 	 writing post-exec report to /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt/_report/report.rst
# 170802-12:22:23,857 workflow DEBUG:
# 	 Finished running smooth_filt.a0 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/preprocwf/_subject_id_101/smooth_filt
#
# 170802-12:22:23,892 workflow INFO:
# 	 [Job finished] jobname: smooth_filt.a0 jobid: 27
