# %%
#import packages
from os import listdir
from nipype.interfaces.io import DataSink, SelectFiles, DataGrabber # Data i/o
from nipype.interfaces.utility import IdentityInterface, Function     # utility
from nipype.pipeline.engine import Node, Workflow, JoinNode        # pypeline engine

from nipype.interfaces.fsl.model import Randomise, GLM, Cluster
from nipype.interfaces.freesurfer.model import Binarize
from nipype.interfaces.fsl.utils import ImageMeants, Merge, Split
from nipype.interfaces.fsl.maths import ApplyMask

#set output file type for FSL to NIFTI
from nipype.interfaces.fsl.preprocess import FSLCommand
FSLCommand.set_default_output_type('NIFTI')

# MATLAB setup - Specify path to current SPM and the MATLAB's default mode
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('~/spm12')
MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")

# Set study variables
#studyhome = '/Users/catcamacho/Box/FFnHK-Oddball/RESTINGSTATE'
studyhome = '/home/camachocm2/Box_home/CARS_rest'
raw_data = studyhome + '/raw'
preproc_dir = studyhome + '/proc/preproc'
output_dir = studyhome + '/proc/analysis'
workflow_dir = studyhome + '/workflows'
roi_dir = studyhome + '/ROIs'
group_con = studyhome + '/misc/tcon.con'
group_mat = studyhome + '/misc/design.mat'
proc_cores = 2

#subjects_list = ['101']
subjects_list = open(studyhome + '/misc/subjects.txt').read().splitlines()

template_brain = studyhome + '/templates/MNI152_T1_2mm_brain.nii'

# ROIs for connectivity analysis
Lamyg = roi_dir + '/L_amyg_anatomical.nii'
Ramyg = roi_dir + '/R_amyg_anatomical.nii'

ROIs = [Lamyg, Ramyg]
rois = ['L_amyg','R_amyg']

min_clust_size = 25

# %%
## File handling
# Identity node- select subjects
infosource = Node(IdentityInterface(fields=['subject_id','ROIs']),
                     name='infosource')
infosource.iterables = [('subject_id', subjects_list),('ROIs',ROIs)]


# Data grabber- select fMRI and ROIs
templates = {'orig_func': preproc_dir + '/smoothed_filt_func/{subject_id}/func_filtered_smooth.nii'}
selectfiles = Node(SelectFiles(templates), name='selectfiles')

# Datasink- where our select outputs will go
datasink = Node(DataSink(), name='datasink')
datasink.inputs.base_directory = output_dir
datasink.inputs.container = output_dir
substitutions = [('_subject_id_', ''),
                ('_ROIs_..Users..catcamacho..Box..BABIES..ROIs..','')]
datasink.inputs.substitutions = substitutions

# %%
## Seed-based level 1

# Extract ROI timeseries
ROI_timeseries = Node(ImageMeants(), name='ROI_timeseries', iterfield='mask')

def converthex(orig):
    from numpy import genfromtxt, savetxt
    from os.path import abspath
    
    orig = genfromtxt(orig, delimiter='  ', dtype=None, skip_header=0)
    new = 'func_roi_ts.txt'
    savetxt(new, orig, delimiter='  ')
    
    new_file = abspath(new)
    return(new_file)

converthex = Node(name='converthex', 
                  interface=Function(input_names=['orig'], 
                                     output_names=['new_file'], 
                                     function=converthex))

# model ROI connectivity
glm = Node(GLM(out_file='betas.nii',out_cope='cope.nii'), name='glm', iterfield='design')

# %%
sbc1_workflow = Workflow(name='sbc1_workflow')
sbc1_workflow.connect([(infosource,selectfiles,[('subject_id','subject_id')]),
                       (selectfiles,ROI_timeseries,[('orig_func','in_file')]),
                       (infosource,ROI_timeseries,[('ROIs','mask')]),
                       (ROI_timeseries,converthex,[('out_file','orig')]),
                       (converthex,glm,[('new_file','design')]),
                       (selectfiles,glm,[('orig_func','in_file')]),
                       (converthex, datasink, [('new_file','roi_ts')]),
                       (glm,datasink,[('out_cope','glm_seed_copes')]),
                       (glm,datasink,[('out_file','glm_betas')])
                      ])
sbc1_workflow.base_dir = workflow_dir
sbc1_workflow.write_graph(graph2use='flat')
sbc1_workflow.run('MultiProc', plugin_args={'n_procs': proc_cores})
# Out:
# 170804-09:50:06,144 workflow INFO:
# 	 Generated workflow graph: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/graph.dot.png (graph2use=flat, simple_form=True).
# 170804-09:50:06,203 workflow INFO:
# 	 Workflow sbc1_workflow settings: ['check', 'execution', 'logging']
# 170804-09:50:06,481 workflow INFO:
# 	 Running in parallel.
# 170804-09:50:06,488 workflow INFO:
# 	 Executing: selectfiles.a40 ID: 0
# 170804-09:50:06,492 workflow INFO:
# 	 Executing: selectfiles.a69 ID: 1
# 170804-09:50:06,491 workflow INFO:
# 	 Executing node selectfiles.a40 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..L_amyg_anatomical.nii_subject_id_235/selectfiles
# 170804-09:50:06,496 workflow INFO:
# 	 Executing node selectfiles.a69 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_211/selectfiles
# 170804-09:50:06,512 workflow ERROR:
# 	 [u'Node selectfiles.a40 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,514 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a40-4eb936a8-cbb0-4003-8245-3696e4f21cfa.pklz
# 170804-09:50:06,516 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_235/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,522 workflow ERROR:
# 	 [u'Node selectfiles.a69 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,524 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a69-652a8e69-f61a-43a4-a341-4ecb7ce6b021.pklz
# 170804-09:50:06,525 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_211/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,533 workflow INFO:
# 	 Executing: selectfiles.a39 ID: 2
# 170804-09:50:06,538 workflow INFO:
# 	 Executing: selectfiles.a82 ID: 3
# 170804-09:50:06,541 workflow INFO:
# 	 Executing node selectfiles.a39 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..L_amyg_anatomical.nii_subject_id_233/selectfiles
# 170804-09:50:06,542 workflow INFO:
# 	 Executing node selectfiles.a82 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_233/selectfiles
# 170804-09:50:06,555 workflow ERROR:
# 	 [u'Node selectfiles.a39 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,556 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a39-20d7d0db-36ba-47c8-895a-33629c54243a.pklz
# 170804-09:50:06,556 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_233/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,562 workflow ERROR:
# 	 [u'Node selectfiles.a82 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,563 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a82-6ec82724-91d4-4fc4-857d-5700ce860d71.pklz
# 170804-09:50:06,563 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_233/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,571 workflow INFO:
# 	 Executing: selectfiles.a38 ID: 7
# 170804-09:50:06,573 workflow INFO:
# 	 Executing: selectfiles.a53 ID: 8
# 170804-09:50:06,573 workflow INFO:
# 	 Executing node selectfiles.a38 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..L_amyg_anatomical.nii_subject_id_230/selectfiles
# 170804-09:50:06,575 workflow INFO:
# 	 Executing node selectfiles.a53 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_118/selectfiles
# 170804-09:50:06,583 workflow ERROR:
# 	 [u'Node selectfiles.a38 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,584 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a38-fcd51bc2-76ef-4f4f-bae5-15b18ebab6ad.pklz
# 170804-09:50:06,586 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_230/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,593 workflow INFO:
# 	 Executing: selectfiles.a78 ID: 9
# 170804-09:50:06,608 workflow INFO:
# 	 Executing node selectfiles.a78 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_223/selectfiles
# 170804-09:50:06,617 workflow ERROR:
# 	 [u'Node selectfiles.a53 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,618 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a53-000c1a63-3f80-4909-a225-ed51c19637c7.pklz
# 170804-09:50:06,620 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_118/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,625 workflow ERROR:
# 	 [u'Node selectfiles.a78 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,626 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a78-f962aa7f-1f91-4126-a339-afd1b3753808.pklz
# 170804-09:50:06,627 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_223/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,635 workflow INFO:
# 	 Executing: selectfiles.a37 ID: 13
# 170804-09:50:06,636 workflow INFO:
# 	 Executing: selectfiles.a72 ID: 14
# 170804-09:50:06,638 workflow INFO:
# 	 Executing node selectfiles.a37 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..L_amyg_anatomical.nii_subject_id_229/selectfiles
# 170804-09:50:06,639 workflow INFO:
# 	 Executing node selectfiles.a72 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_214/selectfiles
# 170804-09:50:06,654 workflow ERROR:
# 	 [u'Node selectfiles.a37 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,654 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a37-f613921f-a63c-41b2-b43e-b3771f9a5eb6.pklz
# 170804-09:50:06,657 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_229/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,663 workflow ERROR:
# 	 [u'Node selectfiles.a72 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,664 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a72-af27eb56-8caa-4a25-a87a-862edb4ff638.pklz
# 170804-09:50:06,665 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_214/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
# 170804-09:50:06,673 workflow INFO:
# 	 Executing: selectfiles.a36 ID: 18
# 170804-09:50:06,675 workflow INFO:
# 	 Executing: selectfiles.a35 ID: 22
# 170804-09:50:06,677 workflow INFO:
# 	 Executing node selectfiles.a36 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..L_amyg_anatomical.nii_subject_id_227/selectfiles
# 170804-09:50:06,677 workflow INFO:
# 	 Executing node selectfiles.a35 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..L_amyg_anatomical.nii_subject_id_223/selectfiles
# 170804-09:50:06,709 workflow ERROR:
# 	 [u'Node selectfiles.a36 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,711 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a36-e32087ad-25c0-4eab-8af1-c57ebcb0b3d9.pklz
# 170804-09:50:06,713 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_227/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,718 workflow ERROR:
# 	 [u'Node selectfiles.a35 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,719 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a35-7e864d88-75e3-4f8a-a277-f20e135edb4e.pklz
# 170804-09:50:06,719 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_223/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,727 workflow INFO:
# 	 Executing: selectfiles.a70 ID: 23
# 170804-09:50:06,728 workflow INFO:
# 	 Executing: selectfiles.a51 ID: 25
# 170804-09:50:06,730 workflow INFO:
# 	 Executing node selectfiles.a51 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_115/selectfiles
# 170804-09:50:06,730 workflow INFO:
# 	 Executing node selectfiles.a70 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_212/selectfiles
# 170804-09:50:06,742 workflow ERROR:
# 	 [u'Node selectfiles.a51 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,743 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a51-2973ae80-0b13-4821-9d38-d2f3b2e6e8b2.pklz
# 170804-09:50:06,745 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_115/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,752 workflow INFO:
# 	 Executing: selectfiles.a79 ID: 26
# 170804-09:50:06,754 workflow INFO:
# 	 Executing node selectfiles.a79 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_227/selectfiles
# 170804-09:50:06,753 workflow ERROR:
# 	 [u'Node selectfiles.a70 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,758 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a70-60e8d87e-6a0e-4194-8218-aeeeae9b7015.pklz
# 170804-09:50:06,759 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_212/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,765 workflow ERROR:
# 	 [u'Node selectfiles.a79 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,768 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a79-bc5bdc15-da6c-4729-b645-2d7ea9469463.pklz
# 170804-09:50:06,768 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_227/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
# 170804-09:50:06,776 workflow INFO:
# 	 Executing: selectfiles.a50 ID: 28
# 170804-09:50:06,778 workflow INFO:
# 	 Executing: selectfiles.a81 ID: 29
# 170804-09:50:06,779 workflow INFO:
# 	 Executing node selectfiles.a50 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_113/selectfiles
# 170804-09:50:06,782 workflow INFO:
# 	 Executing node selectfiles.a81 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_230/selectfiles
# 170804-09:50:06,792 workflow ERROR:
# 	 [u'Node selectfiles.a50 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,793 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a50-fa4a0d62-c4d1-426d-b108-b30d8fd0dab9.pklz
# 170804-09:50:06,794 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_113/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,800 workflow ERROR:
# 	 [u'Node selectfiles.a81 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,806 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a81-cbba8016-5559-49b2-8dd3-4e721cf3cf92.pklz
# 170804-09:50:06,807 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_230/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,815 workflow INFO:
# 	 Executing: selectfiles.a02 ID: 33
# 170804-09:50:06,822 workflow INFO:
# 	 Executing: selectfiles.a49 ID: 37
# 170804-09:50:06,823 workflow INFO:
# 	 Executing node selectfiles.a02 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..L_amyg_anatomical.nii_subject_id_105/selectfiles
# 170804-09:50:06,830 workflow INFO:
# 	 Executing node selectfiles.a49 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_112/selectfiles
# 170804-09:50:06,831 workflow ERROR:
# 	 [u'Node selectfiles.a02 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,835 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a02-730bea01-ef57-4da3-be22-7b00a65b715d.pklz
# 170804-09:50:06,837 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_105/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,842 workflow ERROR:
# 	 [u'Node selectfiles.a49 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,844 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a49-5696ec34-175f-4d16-9724-c045b44db0f6.pklz
# 170804-09:50:06,845 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_112/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,852 workflow INFO:
# 	 Executing: selectfiles.a77 ID: 41
# 170804-09:50:06,854 workflow INFO:
# 	 Executing: selectfiles.a48 ID: 42
# 170804-09:50:06,854 workflow INFO:
# 	 Executing node selectfiles.a77 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_222/selectfiles
# 170804-09:50:06,857 workflow INFO:
# 	 Executing node selectfiles.a48 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_111/selectfiles
# 170804-09:50:06,865 workflow ERROR:
# 	 [u'Node selectfiles.a77 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,866 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a77-a4a30bfd-df5a-4413-bbae-c17a02560130.pklz
# 170804-09:50:06,867 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_222/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,872 workflow ERROR:
# 	 [u'Node selectfiles.a48 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,873 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a48-9413e13f-43e3-4be9-b680-dc7eb71d8b9f.pklz
# 170804-09:50:06,876 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_111/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,883 workflow INFO:
# 	 Executing: selectfiles.a76 ID: 46
# 170804-09:50:06,884 workflow INFO:
# 	 Executing: selectfiles.a47 ID: 47
# 170804-09:50:06,886 workflow INFO:
# 	 Executing node selectfiles.a76 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_221/selectfiles
# 170804-09:50:06,893 workflow INFO:
# 	 Executing node selectfiles.a47 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_110/selectfiles
# 170804-09:50:06,895 workflow ERROR:
# 	 [u'Node selectfiles.a76 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,898 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a76-23ad8ba7-d0fa-495a-89a5-d6ac3df1457e.pklz
# 170804-09:50:06,900 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_221/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,908 workflow INFO:
# 	 Executing: selectfiles.a46 ID: 54
# 170804-09:50:06,909 workflow ERROR:
# 	 [u'Node selectfiles.a47 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,910 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a47-7bac53ec-7a9c-4448-a50c-2ac49f7ae03d.pklz
# 170804-09:50:06,911 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_110/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,913 workflow INFO:
# 	 Executing node selectfiles.a46 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_107/selectfiles
# 170804-09:50:06,918 workflow INFO:
# 	 Executing: selectfiles.a28 ID: 57
# 170804-09:50:06,925 workflow ERROR:
# 	 [u'Node selectfiles.a46 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,926 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a46-61d94bbd-5c89-4e30-b5ad-86acf8120d34.pklz
# 170804-09:50:06,926 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_107/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
# 170804-09:50:06,930 workflow INFO:
# 	 Executing node selectfiles.a28 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..L_amyg_anatomical.nii_subject_id_213/selectfiles
# 170804-09:50:06,934 workflow INFO:
# 	 Executing: selectfiles.a56 ID: 58
# 170804-09:50:06,941 workflow INFO:
# 	 Executing node selectfiles.a56 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..R_amyg_anatomical.nii_subject_id_122/selectfiles
# 170804-09:50:06,946 workflow ERROR:
# 	 [u'Node selectfiles.a28 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,947 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a28-b9c3dd0f-de0c-4ba8-9b16-9b8edc2b1683.pklz
# 170804-09:50:06,947 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_213/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,954 workflow INFO:
# 	 Executing: selectfiles.a27 ID: 62
# 170804-09:50:06,957 workflow INFO:
# 	 Executing node selectfiles.a27 in dir: /home/camachocm2/Box_home/CARS_rest/workflows/sbc1_workflow/_ROIs_..home..camachocm2..Box_home..CARS_rest..ROIs..L_amyg_anatomical.nii_subject_id_212/selectfiles
# 170804-09:50:06,964 workflow ERROR:
# 	 [u'Node selectfiles.a56 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,964 workflow INFO:
# 	 Saving crash info to /home/camachocm2/repos/preschool_rest/crash-20170804-095006-camachocm2-selectfiles.a56-98dca00e-0e57-4592-abf4-4feb365f2fc0.pklz
# 170804-09:50:06,965 workflow INFO:
# 	 Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/multiproc.py", line 52, in run_node
#     result['result'] = node.run(updatehash=updatehash)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 372, in run
#     self._run_interface()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 482, in _run_interface
#     self._result = self._run_command(execute)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/nodes.py", line 613, in _run_command
#     result = self._interface.run()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1082, in run
#     outputs = self.aggregate_outputs(runtime)
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/base.py", line 1153, in aggregate_outputs
#     predicted_outputs = self._list_outputs()
#   File "/usr/local/lib/python2.7/dist-packages/nipype/interfaces/io.py", line 1313, in _list_outputs
#     raise IOError(msg)
# IOError: No files were found matching orig_func template: /home/camachocm2/Box_home/CARS_rest/proc/preproc/smoothed_filt_func/_subject_id_122/func_filtered_smooth.nii
# Interface SelectFiles failed to run.
#
# 170804-09:50:06,971 workflow ERROR:
# 	 [u'Node selectfiles.a27 failed to run on host camachocm2-optiplex-3020.']
# 170804-09:50:06,971 workflow INFO:
# ...
# 170804-09:50:08,53 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a09-b6a5fabc-0f89-4aa0-8dc4-b4a53914dd61.pklz
# 170804-09:50:08,54 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a10
# 170804-09:50:08,55 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a10-f5d67269-4811-4287-ac3d-7013214a1d9a.pklz
# 170804-09:50:08,55 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a13
# 170804-09:50:08,55 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a13-2c9ed984-f34e-4c4e-9cfc-a26d8839d687.pklz
# 170804-09:50:08,56 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a41
# 170804-09:50:08,56 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a41-6fedcc3c-168d-4ce0-bf02-87670e5967f9.pklz
# 170804-09:50:08,57 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a12
# 170804-09:50:08,57 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a12-4d01b07b-92e6-4e09-8b85-fb90c18f32e2.pklz
# 170804-09:50:08,58 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a11
# 170804-09:50:08,58 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a11-39f1e183-e96c-4346-b185-301912cf27bb.pklz
# 170804-09:50:08,59 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a63
# 170804-09:50:08,59 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a63-9bc46df7-2cb9-4591-8ea5-256fb1207e63.pklz
# 170804-09:50:08,60 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a44
# 170804-09:50:08,60 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a44-da85cb00-3c59-4ad9-86f7-9960fbcbb683.pklz
# 170804-09:50:08,61 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a31
# 170804-09:50:08,61 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a31-27a31c80-6c53-457c-8f05-279eeb55afe9.pklz
# 170804-09:50:08,62 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a62
# 170804-09:50:08,62 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a62-00ba4d5f-f01f-4055-a114-ca20007a426e.pklz
# 170804-09:50:08,63 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a57
# 170804-09:50:08,63 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a57-2fa0cf07-4b6a-4143-9b2d-4f644c305ab4.pklz
# 170804-09:50:08,64 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a61
# 170804-09:50:08,64 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a61-62dac39c-80da-4f44-8a8f-164f105e1745.pklz
# 170804-09:50:08,67 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a60
# 170804-09:50:08,68 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a60-49b7adba-5598-46cb-aed3-1a8466baa3a0.pklz
# 170804-09:50:08,68 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a74
# 170804-09:50:08,69 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a74-98ba6360-fadf-4c45-9034-13e166c2af7f.pklz
# 170804-09:50:08,69 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a32
# 170804-09:50:08,70 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a32-c67ebd66-d2aa-4767-9c58-296813dc4b34.pklz
# 170804-09:50:08,70 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a19
# 170804-09:50:08,71 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a19-c4a900c5-f2fe-463c-8019-d3b0018c135f.pklz
# 170804-09:50:08,72 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a59
# 170804-09:50:08,72 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a59-1f4e35d8-3e43-4c53-b8c0-3baa5f7dc430.pklz
# 170804-09:50:08,73 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a58
# 170804-09:50:08,73 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a58-d9e181f8-cba2-424d-92a4-cdd334b5c073.pklz
# 170804-09:50:08,74 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a05
# 170804-09:50:08,74 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a05-abecb374-dca0-483b-90b1-5b6bd0522c89.pklz
# 170804-09:50:08,75 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a03
# 170804-09:50:08,75 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a03-542344d4-0bd1-4d6f-b19f-7974fecfbc9b.pklz
# 170804-09:50:08,76 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a85
# 170804-09:50:08,76 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a85-c942ddec-9f66-405b-aba5-7719d307f530.pklz
# 170804-09:50:08,77 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a07
# 170804-09:50:08,77 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a07-f61c71bd-3734-4dbb-99a9-11322fcf5b65.pklz
# 170804-09:50:08,78 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a06
# 170804-09:50:08,78 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a06-18370dcd-61c2-4136-aa2a-9c3a958e6016.pklz
# 170804-09:50:08,79 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a00
# 170804-09:50:08,79 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a00-5215590c-41f2-47bf-9fb2-31e6f7f8187a.pklz
# 170804-09:50:08,84 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a04
# 170804-09:50:08,85 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a04-9be81c8c-5198-413a-b6a1-6dcbec3dd516.pklz
# 170804-09:50:08,86 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a71
# 170804-09:50:08,86 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a71-9c5f143c-95b5-4461-935a-cb76ca909fd2.pklz
# 170804-09:50:08,87 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a23
# 170804-09:50:08,87 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a23-010a6ee7-3474-459c-937b-600f4603ea5a.pklz
# 170804-09:50:08,88 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a42
# 170804-09:50:08,88 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a42-69e44de3-8608-40eb-b32a-def23cae9f1c.pklz
# 170804-09:50:08,89 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a68
# 170804-09:50:08,89 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a68-cfc951f1-6dad-4aeb-8862-d9867cdd6221.pklz
# 170804-09:50:08,90 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a22
# 170804-09:50:08,90 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a22-5cddf231-1388-4dbf-8a32-5f1470f94eae.pklz
# 170804-09:50:08,91 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a84
# 170804-09:50:08,98 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a84-a6c116a3-3306-409d-afae-cfb04dbf4877.pklz
# 170804-09:50:08,98 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a67
# 170804-09:50:08,99 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a67-1bbe4d10-e724-418d-8c65-e3ada5ab108b.pklz
# 170804-09:50:08,99 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a21
# 170804-09:50:08,101 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a21-7e7644e6-6065-4d6d-81fb-4ce360f144ee.pklz
# 170804-09:50:08,101 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a55
# 170804-09:50:08,101 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a55-24664ac9-a3c0-427f-a051-2d4879a8d39f.pklz
# 170804-09:50:08,102 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a80
# 170804-09:50:08,102 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a80-464c47df-394b-4b88-8393-1ba6fe76f5dd.pklz
# 170804-09:50:08,103 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a29
# 170804-09:50:08,103 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a29-6dff3fe1-8898-446b-b861-dddb160f933a.pklz
# 170804-09:50:08,104 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a66
# 170804-09:50:08,104 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a66-4961633c-7479-4e51-afe2-7fd2c369ab76.pklz
# 170804-09:50:08,105 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a20
# 170804-09:50:08,105 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a20-86e3db3b-a79b-4a20-9b24-62b74f1fc845.pklz
# 170804-09:50:08,106 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a01
# 170804-09:50:08,106 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a01-26b23f13-c18d-4729-b314-60b0daab8297.pklz
# 170804-09:50:08,106 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a65
# 170804-09:50:08,107 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a65-d8604f3f-2f85-493a-8c28-8568d9db2b01.pklz
# 170804-09:50:08,107 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a30
# 170804-09:50:08,108 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a30-0afd257e-19aa-4ae8-bb20-d9186a0ba5b6.pklz
# 170804-09:50:08,108 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a64
# 170804-09:50:08,109 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a64-fb751cfe-66e5-4ed9-884a-5cb5afd5a107.pklz
# 170804-09:50:08,110 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a73
# 170804-09:50:08,111 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a73-a780cf6a-6534-42a3-aae4-6d30f0c02d8b.pklz
# 170804-09:50:08,111 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a34
# 170804-09:50:08,112 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a34-13b9ee7a-5690-421a-88a7-c7fb1e44b63e.pklz
# 170804-09:50:08,112 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a16
# 170804-09:50:08,112 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a16-f36e0ddf-5a8d-46ce-bc1f-bcf47ab7b6e4.pklz
# 170804-09:50:08,113 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a83
# 170804-09:50:08,113 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a83-69825398-7d0b-4d50-bb25-035030e0f919.pklz
# 170804-09:50:08,114 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a33
# 170804-09:50:08,114 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a33-eb1d417c-71c6-44d1-91d6-0a0f52f81cdb.pklz
# 170804-09:50:08,117 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a15
# 170804-09:50:08,118 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a15-c404a355-2a12-42d6-b83d-fa149cc8a003.pklz
# 170804-09:50:08,118 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a17
# 170804-09:50:08,121 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a17-ddd7ab8c-374a-43dc-9dd9-1f28c3ee0afb.pklz
# 170804-09:50:08,121 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a14
# 170804-09:50:08,122 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a14-b1417f80-7821-4f36-afc1-9e96d6e3ba64.pklz
# 170804-09:50:08,122 workflow ERROR:
# 	 could not run node: sbc1_workflow.selectfiles.a18
# 170804-09:50:08,123 workflow INFO:
# 	 crashfile: /home/camachocm2/repos/preschool_rest/crash-20170804-095007-camachocm2-selectfiles.a18-1bba297d-02b0-4b23-bc56-9c85c2ed0435.pklz
# 170804-09:50:08,125 workflow INFO:
# 	 ***********************************
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-08f61e85f534> in <module>()
#      11 sbc1_workflow.base_dir = workflow_dir
#      12 sbc1_workflow.write_graph(graph2use='flat')
# ---> 13 sbc1_workflow.run('MultiProc', plugin_args={'n_procs': proc_cores})
#
# /usr/local/lib/python2.7/dist-packages/nipype/pipeline/engine/workflows.pyc in run(self, plugin, plugin_args, updatehash)
#     588         if str2bool(self.config['execution']['create_report']):
#     589             self._write_report_info(self.base_dir, self.name, execgraph)
# --> 590         runner.run(execgraph, updatehash=updatehash, config=self.config)
#     591         datestr = datetime.utcnow().strftime('%Y%m%dT%H%M%S')
#     592         if str2bool(self.config['execution']['write_provenance']):
#
# /usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/base.pyc in run(self, graph, config, updatehash)
#     277
#     278         self._remove_node_dirs()
# --> 279         report_nodes_not_run(notrun)
#     280
#     281         # close any open resources
#
# /usr/local/lib/python2.7/dist-packages/nipype/pipeline/plugins/base.pyc in report_nodes_not_run(notrun)
#      99                 logger.debug(subnode._id)
#     100         logger.info("***********************************")
# --> 101         raise RuntimeError(('Workflow did not execute cleanly. '
#     102                             'Check log for details'))
#     103
#
# RuntimeError: Workflow did not execute cleanly. Check log for details
# Process NonDaemonPoolWorker-2:
# Process NonDaemonPoolWorker-1:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#   File "/usr/lib/python2.7/multiprocessing/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     task = get()
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 376, in get
#     racquire()
# KeyboardInterrupt
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python2.7/multiprocessing/pool.py", line 102, in worker
#     task = get()
#   File "/usr/lib/python2.7/multiprocessing/queues.py", line 378, in get
#     return recv()
# KeyboardInterrupt

# %%
infosource2 = Node(IdentityInterface(fields=['roi']),
                   name='infosource2')
infosource2.iterables = ('roi',rois)


# Data grabber- select fMRI and ROIs
templates = {'roi': 'glm_seed_copes/%s_4mm.nii*/cope.nii'}

datagrabber = Node(DataGrabber(infields=['roi'], 
                               outfields=['roi'],
                               sort_filelist=True,
                               base_directory=output_dir,
                               template='glm_seed_copes/%s_4mm.nii*/cope.nii',
                               field_template=templates,
                               template_args=dict(roi=[['roi']])),
                   name='datagrabber')

# %%
## Level 2

# merge param estimates across all subjects per seed
merge = Node(Merge(dimension='t'),
             name='merge')

# FSL randomise for higher level analysis
highermodel = Node(Randomise(tfce=True,
                             raw_stats_imgs= True,
                             design_mat=group_mat,
                             tcon=group_con),
                   name = 'highermodel')

## Cluster results

# make binary masks of sig clusters
binarize = Node(Binarize(min=0.95, max=1.0), 
                name='binarize', 
                iterfield='in_file')

# mask T-map before clustering
mask_tmaps = Node(ApplyMask(), name='mask_tmaps')

# clusterize and extract cluster stats/peaks
clusterize = Node(Cluster(threshold=2.3, 
                          out_index_file='outindex.nii', 
                          out_localmax_txt_file='localmax.txt'), 
                  name='clusterize')

# make pictures if time

# %%
sbc2_workflow = Workflow(name='sbc2_workflow')
sbc2_workflow.connect([(infosource2,datagrabber,[('roi','roi')]),
                       (datagrabber,merge,[('roi','in_files')]),
                       (merge,highermodel,[('merged_file','in_file')]),

                       (highermodel,datasink,[('t_corrected_p_files','rand_corrp_files')]),
                       (highermodel,datasink,[('tstat_files','rand_tstat_files')])
                      ])
sbc2_workflow.base_dir = workflow_dir
sbc2_workflow.write_graph(graph2use='flat')
sbc2_workflow.run('MultiProc', plugin_args={'n_procs': proc_cores})

# %%
# Identity node- select subjects
infosource3 = Node(IdentityInterface(fields=['roi']),
                   name='infosource3')
infosource3.iterables = [('roi',rois)]


# Data grabber- select fMRI and ROIs
templates = {'pcorrT': output_dir + '/rand_corrp_files/_roi_{roi}/tbss__tfce_corrp_tstat1.nii', 
             'tstat': output_dir + '/rand_tstat_files/_roi_{roi}/tbss__tstat1.nii'}
selectfiles2 = Node(SelectFiles(templates), name='selectfiles2')

# %%
sbc3_workflow = Workflow(name='sbc3_workflow')
sbc3_workflow.connect([(infosource3,selectfiles2, [('roi','roi')]),
                       (selectfiles2, binarize, [('pcorrT','in_file')]),
                       (binarize, mask_tmaps, [('binary_file','mask_file')]),
                       (selectfiles2, mask_tmaps, [('tstat','in_file')]),
                       (mask_tmaps, clusterize, [('out_file','in_file')]),
                       
                       (binarize,datasink,[('binary_file','binary_pval')]),
                       (mask_tmaps,datasink,[('out_file','masked_tmaps')]),
                       (clusterize,datasink,[('index_file','cluster_index_file')]),
                       (clusterize,datasink,[('localmax_txt_file','localmax_txt_file')])
                      ])
sbc3_workflow.base_dir = workflow_dir
sbc3_workflow.write_graph(graph2use='flat')
sbc3_workflow.run('MultiProc', plugin_args={'n_procs': proc_cores})

# %%
# Identity node- select subjects
infosource4 = Node(IdentityInterface(fields=['roi']),
                   name='infosource4')
infosource4.iterables = [('roi',rois)]


# Data grabber- select fMRI and ROIs
templates = {'clusters': output_dir + '/cluster_index_file/_roi_{roi}/outindex.nii', 
             'cluster_table': output_dir + '/localmax_txt_file/_roi_{roi}/cluster_table.txt'}
selectfiles3 = Node(SelectFiles(templates), name='selectfiles3')

# Grab betas for stuff
templates2 = {'roi': 'glm_betas/%s_4mm.nii*-BABIES-T1/betas.nii'}

betagrabber = Node(DataGrabber(infields=['roi'], 
                               outfields=['roi'],
                               sort_filelist=True,
                               base_directory=output_dir,
                               template='glm_betas/%s_4mm.nii*-BABIES-T1/betas.nii',
                               field_template=templates2,
                               template_args=dict(roi=[['roi']])),
                   name='betagrabber')

# %%
# parse clusters table
def determine_clusters(clusters_table, min_clust_size):
    from os import path
    from numpy import genfromtxt
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    clusters = genfromtxt(clusters_table, delimiter='\t', dtype=None, skip_header=1)
    clusters_to_extract = []
    
    for t in clusters:
        if clusters[t][1] >= min_clust_size:
            clusters_to_extract.append(clusters[t][0])
    
    
    return(cluster_index)

det_clust = Node(name='det_clust', 
                 interface=Function(input_names=['clusters_table','min_clust_size'],
                                    output_names=['cluster_index'], 
                                    function=determine_clusters))
det_clust.inputs.min_clust_size=min_clust_size

# separate cluster volumes
split_clusters = Node(Split(dimension='t'), name='split_clusters')

# merge betas together
merge_betas = Node(Merge(dimension='t'), name='merge_betas')

# extract betas for each subject/roi clusters and put in table as fisher's Z scores
def extract_fisherZ(subj_betas, clusters, cluster_table):
    from os import path
    from numpy import genfromtxt, savetxt
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    header = []
    clusters = genfromtxt(clusters_table, delimiter='\t', dtype=None, skip_header=1)
    
    savetxt(file, matrix, delimiter='\t', header=header)

    return(table_path)

extract_fisherZ = Node(name='extract_fisherZ', 
                       interface=Function(input_names=['subj_betas','clusters','cluster_table'],
                                          output_names=['table_path'], 
                                          function=extract_fisherZ))

# %%
sbc4_workflow = Workflow(name='sbc4_workflow')
sbc4_workflow.connect([(infosource4, selectfiles3, [('roi','roi')]),
                       (infosource4, betagrabber, [('roi','roi')]),
                       (selectfiles3, split_clusters, [('clusters','in_file')]),
                       (betagrabber, merge_betas, [('roi','in_files')]),
                       
                       (merge_betas, datasink, [('merged_file','merged_betas')]),
                       (split_clusters, datasink, [('out_files','split_clusters')])
                      ])
sbc4_workflow.base_dir = workflow_dir
sbc4_workflow.write_graph(graph2use='flat')
#sbc4_workflow.run('MultiProc', plugin_args={'n_procs': proc_cores})
